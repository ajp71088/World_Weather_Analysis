# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 772

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | sakakah
# Processing Record 2 of the Set 1 | jamestown
# Processing Record 3 of the Set 1 | bluff
# Processing Record 4 of the Set 1 | trenggalek
# Processing Record 5 of the Set 1 | lensk
# Processing Record 6 of the Set 1 | agadez
# Processing Record 7 of the Set 1 | rikitea
# Processing Record 8 of the Set 1 | airai
# Processing Record 9 of the Set 1 | port alfred
# Processing Record 10 of the Set 1 | atuona
# Processing Record 11 of the Set 1 | port elizabeth
# Processing Record 12 of the Set 1 | port hawkesbury
# Processing Record 13 of the Set 1 | hobart
# Processing Record 14 of the Set 1 | tumannyy
# Processing Record 15 of the Set 1 | pochutla
# Processing Record 16 of the Set 1 | ponta delgada
# Processing Record 17 of the Set 1 | saskylakh
# Processing Record 18 of the Set 1 | ponta do sol
# Processing Record 19 of the Set 1 | gwadar
# Processing Record 20 of the Set 1 | vao
# Processing Record 21 of the Set 1 | faanui
# Processing Record 22 of the Set 1 | vanimo
# Processing Record 23 of the Set 1 | chateauroux
# Processing Record 24 of the Set 1 | punta arenas
# Processing Record 25 of the Set 1 | alyangula
# Processing Record 26 of the Set 1 | saldanha
# Processing Record 27 of the Set 1 | cape town
# Processing Record 28 of the Set 1 | acapulco
# Processing Record 29 of the Set 1 | qaanaaq
# Processing Record 30 of the Set 1 | ponta do sol
# Processing Record 31 of the Set 1 | mataura
# Processing Record 32 of the Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 33 of the Set 1 | kalmunai
# Processing Record 34 of the Set 1 | albany
# Processing Record 35 of the Set 1 | isangel
# Processing Record 36 of the Set 1 | fontem
# Processing Record 37 of the Set 1 | romny
# Processing Record 38 of the Set 1 | dukat
# Processing Record 39 of the Set 1 | keningau
# Processing Record 40 of the Set 1 | vaini
# Processing Record 41 of the Set 1 | ust-kan
# Processing Record 42 of the Set 1 | coxim
# Processing Record 43 of the Set 1 | tuktoyaktuk
# Processing Record 44 of the Set 1 | georgetown
# Processing Record 45 of the Set 1 | butaritari
# Processing Record 46 of the Set 1 | berlevag
# Processing Record 47 of the Set 1 | araouane
# Processing Record 48 of the Set 1 | ankang
# Processing Record 49 of the Set 1 | hithadhoo
# Processing Record 50 of the Set 1 | avarua
# Processing Record 1 of the Set 2 | wanning
# Processing Record 2 of the Set 2 | corpus christi
# Processing Record 3 of the Set 2 | sainte-anne-des-monts
# Processing Record 4 of the Set 2 | castro
# Processing Record 5 of the Set 2 | cherskiy
# Processing Record 6 of the Set 2 | meridian
# Processing Record 7 of the Set 2 | hobyo
# Processing Record 8 of the Set 2 | upernavik
# Processing Record 9 of the Set 2 | bredasdorp
# Processing Record 10 of the Set 2 | stoyba
# Processing Record 11 of the Set 2 | ngunguru
# Processing Record 12 of the Set 2 | brokopondo
# Processing Record 13 of the Set 2 | westport
# Processing Record 14 of the Set 2 | raudeberg
# Processing Record 15 of the Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of the Set 2 | cayenne
# Processing Record 17 of the Set 2 | sjovegan
# Processing Record 18 of the Set 2 | richards bay
# Processing Record 19 of the Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 20 of the Set 2 | barrow
# Processing Record 21 of the Set 2 | tual
# Processing Record 22 of the Set 2 | butte
# Processing Record 23 of the Set 2 | college
# Processing Record 24 of the Set 2 | kaitangata
# Processing Record 25 of the Set 2 | hermanus
# Processing Record 26 of the Set 2 | leningradskiy
# Processing Record 27 of the Set 2 | dunyapur
# Processing Record 28 of the Set 2 | jati
# Processing Record 29 of the Set 2 | fort nelson
# Processing Record 30 of the Set 2 | ushuaia
# Processing Record 31 of the Set 2 | ostrovnoy
# Processing Record 32 of the Set 2 | puerto ayora
# Processing Record 33 of the Set 2 | bethel
# Processing Record 34 of the Set 2 | kapaa
# Processing Record 35 of the Set 2 | zuidhorn
# Processing Record 36 of the Set 2 | jumla
# Processing Record 37 of the Set 2 | caravelas
# Processing Record 38 of the Set 2 | nago
# Processing Record 39 of the Set 2 | pambuhan
# Processing Record 40 of the Set 2 | kelo
# Processing Record 41 of the Set 2 | ratnagiri
# Processing Record 42 of the Set 2 | omsukchan
# Processing Record 43 of the Set 2 | souillac
# Processing Record 44 of the Set 2 | sitka
# Processing Record 45 of the Set 2 | champerico
# Processing Record 46 of the Set 2 | asau
# Processing Record 47 of the Set 2 | illoqqortoormiut
# Processing Record 48 of the Set 2 | komsomolskiy
# Processing Record 49 of the Set 2 | port lincoln
# Processing Record 50 of the Set 2 | paradwip
# Processing Record 1 of the Set 3 | yellowknife
# Processing Record 2 of the Set 3 | irituia
# Processing Record 3 of the Set 3 | chapais
# Processing Record 4 of the Set 3 | pacifica
# Processing Record 5 of the Set 3 | sinnamary
# Processing Record 6 of the Set 3 | fairbanks
# Processing Record 7 of the Set 3 | azad shahr
# Processing Record 8 of the Set 3 | peleduy
# Processing Record 9 of the Set 3 | port blair
# Processing Record 10 of the Set 3 | port hardy
# Processing Record 11 of the Set 3 | nizhneyansk
# Processing Record 12 of the Set 3 | pangnirtung
# Processing Record 13 of the Set 3 | qasigiannguit
# Processing Record 14 of the Set 3 | ormond beach
# Processing Record 15 of the Set 3 | talnakh
# Processing Record 16 of the Set 3 | touros
# Processing Record 17 of the Set 3 | lasa
# Processing Record 18 of the Set 3 | sambava
# City not found. Skipping...
# Processing Record 19 of the Set 3 | kahului
# Processing Record 20 of the Set 3 | busselton
# Processing Record 21 of the Set 3 | luba
# Processing Record 22 of the Set 3 | labuhan
# Processing Record 23 of the Set 3 | laguna
# Processing Record 24 of the Set 3 | khasan
# Processing Record 25 of the Set 3 | grindavik
# Processing Record 26 of the Set 3 | pervomayskoye
# Processing Record 27 of the Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 28 of the Set 3 | kodiak
# Processing Record 29 of the Set 3 | kirakira
# Processing Record 30 of the Set 3 | iqaluit
# Processing Record 31 of the Set 3 | sevlievo
# Processing Record 32 of the Set 3 | hamilton
# Processing Record 33 of the Set 3 | jibuti
# Processing Record 34 of the Set 3 | chokurdakh
# Processing Record 35 of the Set 3 | pevek
# Processing Record 36 of the Set 3 | podor
# Processing Record 37 of the Set 3 | narsaq
# Processing Record 38 of the Set 3 | luocheng
# Processing Record 39 of the Set 3 | norman wells
# Processing Record 40 of the Set 3 | jinchang
# Processing Record 41 of the Set 3 | klaksvik
# Processing Record 42 of the Set 3 | torbay
# Processing Record 43 of the Set 3 | caracuaro
# Processing Record 44 of the Set 3 | termiz
# Processing Record 45 of the Set 3 | nikolskoye
# Processing Record 46 of the Set 3 | hilo
# Processing Record 47 of the Set 3 | palmer
# Processing Record 48 of the Set 3 | camapua
# Processing Record 49 of the Set 3 | hammerfest
# Processing Record 50 of the Set 3 | lebu
# Processing Record 1 of the Set 4 | yumen
# Processing Record 2 of the Set 4 | nguiu
# Processing Record 3 of the Set 4 | sao joao da barra
# Processing Record 4 of the Set 4 | arraial do cabo
# Processing Record 5 of the Set 4 | talcher
# Processing Record 6 of the Set 4 | mocambique
# City not found. Skipping...
# Processing Record 7 of the Set 4 | clyde river
# Processing Record 8 of the Set 4 | funadhoo
# Processing Record 9 of the Set 4 | ilulissat
# Processing Record 10 of the Set 4 | longyearbyen
# Processing Record 11 of the Set 4 | sehithwa
# Processing Record 12 of the Set 4 | kasongo-lunda
# Processing Record 13 of the Set 4 | lafiagi
# Processing Record 14 of the Set 4 | weiser
# Processing Record 15 of the Set 4 | grand-santi
# Processing Record 16 of the Set 4 | miyoshi
# Processing Record 17 of the Set 4 | mar del plata
# Processing Record 18 of the Set 4 | lufilufi
# City not found. Skipping...
# Processing Record 19 of the Set 4 | mount gambier
# Processing Record 20 of the Set 4 | boende
# Processing Record 21 of the Set 4 | hovd
# Processing Record 22 of the Set 4 | aykhal
# Processing Record 23 of the Set 4 | mackay
# Processing Record 24 of the Set 4 | stonewall
# Processing Record 25 of the Set 4 | abu samrah
# Processing Record 26 of the Set 4 | new norfolk
# Processing Record 27 of the Set 4 | cidreira
# Processing Record 28 of the Set 4 | marcona
# City not found. Skipping...
# Processing Record 29 of the Set 4 | truth or consequences
# Processing Record 30 of the Set 4 | mahebourg
# Processing Record 31 of the Set 4 | kununurra
# Processing Record 32 of the Set 4 | saint-augustin
# Processing Record 33 of the Set 4 | oga
# Processing Record 34 of the Set 4 | amderma
# Processing Record 35 of the Set 4 | autun
# Processing Record 36 of the Set 4 | bambanglipuro
# Processing Record 37 of the Set 4 | kloulklubed
# Processing Record 38 of the Set 4 | dikson
# Processing Record 39 of the Set 4 | la uribe
# City not found. Skipping...
# Processing Record 40 of the Set 4 | mount isa
# Processing Record 41 of the Set 4 | deh rawud
# City not found. Skipping...
# Processing Record 42 of the Set 4 | ust-uda
# Processing Record 43 of the Set 4 | dryden
# Processing Record 44 of the Set 4 | bengkulu
# Processing Record 45 of the Set 4 | sao filipe
# Processing Record 46 of the Set 4 | casas grandes
# Processing Record 47 of the Set 4 | barentsburg
# Processing Record 48 of the Set 4 | yulara
# Processing Record 49 of the Set 4 | nantucket
# Processing Record 50 of the Set 4 | kurumoch
# Processing Record 1 of the Set 5 | amapa
# Processing Record 2 of the Set 5 | inirida
# City not found. Skipping...
# Processing Record 3 of the Set 5 | rawson
# Processing Record 4 of the Set 5 | hambantota
# Processing Record 5 of the Set 5 | nurota
# Processing Record 6 of the Set 5 | ornskoldsvik
# Processing Record 7 of the Set 5 | half moon bay
# Processing Record 8 of the Set 5 | thompson
# Processing Record 9 of the Set 5 | harper
# Processing Record 10 of the Set 5 | pueblo
# Processing Record 11 of the Set 5 | boa vista
# Processing Record 12 of the Set 5 | carutapera
# Processing Record 13 of the Set 5 | goderich
# Processing Record 14 of the Set 5 | ordubad
# Processing Record 15 of the Set 5 | saint-philippe
# Processing Record 16 of the Set 5 | carnarvon
# Processing Record 17 of the Set 5 | mutsu
# Processing Record 18 of the Set 5 | dicabisagan
# Processing Record 19 of the Set 5 | lorengau
# Processing Record 20 of the Set 5 | ingham
# Processing Record 21 of the Set 5 | beloha
# City not found. Skipping...
# Processing Record 22 of the Set 5 | hervey bay
# Processing Record 23 of the Set 5 | taoudenni
# Processing Record 24 of the Set 5 | teterow
# Processing Record 25 of the Set 5 | nemuro
# Processing Record 26 of the Set 5 | sentyabrskiy
# Processing Record 27 of the Set 5 | napier
# Processing Record 28 of the Set 5 | honiara
# Processing Record 29 of the Set 5 | rio grande
# Processing Record 30 of the Set 5 | porto santo
# Processing Record 31 of the Set 5 | codrington
# Processing Record 32 of the Set 5 | dhidhdhoo
# Processing Record 33 of the Set 5 | milingimbi
# Processing Record 34 of the Set 5 | gizo
# Processing Record 35 of the Set 5 | tasiilaq
# Processing Record 36 of the Set 5 | bilibino
# Processing Record 37 of the Set 5 | karratha
# Processing Record 38 of the Set 5 | warwick
# Processing Record 39 of the Set 5 | hasaki
# Processing Record 40 of the Set 5 | ribeira grande
# Processing Record 41 of the Set 5 | muros
# Processing Record 42 of the Set 5 | alappuzha
# Processing Record 43 of the Set 5 | khatanga
# Processing Record 44 of the Set 5 | almeirim
# Processing Record 45 of the Set 5 | jishu
# Processing Record 46 of the Set 5 | huanren
# Processing Record 47 of the Set 5 | adrar
# Processing Record 48 of the Set 5 | biltine
# Processing Record 49 of the Set 5 | lompoc
# Processing Record 50 of the Set 5 | sur
# Processing Record 1 of the Set 6 | severo-kurilsk
# Processing Record 2 of the Set 6 | viytivka
# Processing Record 3 of the Set 6 | voznesenye
# Processing Record 4 of the Set 6 | itarema
# Processing Record 5 of the Set 6 | tiksi
# Processing Record 6 of the Set 6 | la ronge
# Processing Record 7 of the Set 6 | oranjestad
# Processing Record 8 of the Set 6 | krasnaya gora
# Processing Record 9 of the Set 6 | camacha
# Processing Record 10 of the Set 6 | ofaqim
# Processing Record 11 of the Set 6 | maceio
# Processing Record 12 of the Set 6 | bonthe
# Processing Record 13 of the Set 6 | ascension
# Processing Record 14 of the Set 6 | stephenville
# Processing Record 15 of the Set 6 | grand island
# Processing Record 16 of the Set 6 | utiroa
# Processing Record 17 of the Set 6 | gavrilov posad
# Processing Record 18 of the Set 6 | slavuta
# Processing Record 19 of the Set 6 | buckeye
# Processing Record 20 of the Set 6 | kawana waters
# Processing Record 21 of the Set 6 | sola
# Processing Record 22 of the Set 6 | novyy urengoy
# Processing Record 23 of the Set 6 | mbandaka
# Processing Record 24 of the Set 6 | los llanos de aridane
# Processing Record 25 of the Set 6 | ovalle
# Processing Record 26 of the Set 6 | chuy
# Processing Record 27 of the Set 6 | burnie
# Processing Record 28 of the Set 6 | coquimbo
# Processing Record 29 of the Set 6 | tete
# City not found. Skipping...
# Processing Record 30 of the Set 6 | trinidad
# City not found. Skipping...
# Processing Record 31 of the Set 6 | east london
# Processing Record 32 of the Set 6 | eyl
# Processing Record 33 of the Set 6 | kolda
# Processing Record 34 of the Set 6 | zhanaozen
# Processing Record 35 of the Set 6 | makhu
# Processing Record 36 of the Set 6 | chihuahua
# Processing Record 37 of the Set 6 | samana
# Processing Record 38 of the Set 6 | aklavik
# Processing Record 39 of the Set 6 | vila
# Processing Record 40 of the Set 6 | usta muhammad
# Processing Record 41 of the Set 6 | oktyabrskiy
# Processing Record 42 of the Set 6 | simbahan
# Processing Record 43 of the Set 6 | teluk nibung
# Processing Record 44 of the Set 6 | chanika
# Processing Record 45 of the Set 6 | lata
# Processing Record 46 of the Set 6 | vila franca do campo
# Processing Record 47 of the Set 6 | kudahuvadhoo
# Processing Record 48 of the Set 6 | husavik
# Processing Record 49 of the Set 6 | bambous virieux
# Processing Record 50 of the Set 6 | vila velha
# Processing Record 1 of the Set 7 | victoria
# Processing Record 2 of the Set 7 | durban
# Processing Record 3 of the Set 7 | tymovskoye
# Processing Record 4 of the Set 7 | mehamn
# Processing Record 5 of the Set 7 | tura
# Processing Record 6 of the Set 7 | belushya guba
# Processing Record 7 of the Set 7 | yerbogachen
# Processing Record 8 of the Set 7 | whitianga
# Processing Record 9 of the Set 7 | ulaanbaatar
# Processing Record 10 of the Set 7 | osoyoos
# Processing Record 11 of the Set 7 | cayambe
# Processing Record 12 of the Set 7 | culebra
# Processing Record 13 of the Set 7 | pryozerne
# Processing Record 14 of the Set 7 | ust-tsilma
# Processing Record 15 of the Set 7 | ust-kulom
# Processing Record 16 of the Set 7 | porto torres
# Processing Record 17 of the Set 7 | caraballeda
# Processing Record 18 of the Set 7 | padang
# Processing Record 19 of the Set 7 | north platte
# Processing Record 20 of the Set 7 | nayoro
# Processing Record 21 of the Set 7 | jiuquan
# Processing Record 22 of the Set 7 | feijo
# Processing Record 23 of the Set 7 | fortuna
# Processing Record 24 of the Set 7 | paamiut
# Processing Record 25 of the Set 7 | masjed-e soleyman
# Processing Record 26 of the Set 7 | mys shmidta
# Processing Record 27 of the Set 7 | umm lajj
# Processing Record 28 of the Set 7 | flagstaff
# Processing Record 29 of the Set 7 | mahajanga
# City not found. Skipping...
# Processing Record 30 of the Set 7 | kruisfontein
# Processing Record 31 of the Set 7 | sao jose da coroa grande
# Processing Record 32 of the Set 7 | chifeng
# Processing Record 33 of the Set 7 | dunedin
# Processing Record 34 of the Set 7 | mogadishu
# Processing Record 35 of the Set 7 | meulaboh
# Processing Record 36 of the Set 7 | coihaique
# Processing Record 37 of the Set 7 | rungata
# Processing Record 38 of the Set 7 | antsohihy
# City not found. Skipping...
# Processing Record 39 of the Set 7 | bandarbeyla
# Processing Record 40 of the Set 7 | yarada
# Processing Record 41 of the Set 7 | ishigaki
# Processing Record 42 of the Set 7 | parana
# Processing Record 43 of the Set 7 | boca do acre
# Processing Record 44 of the Set 7 | siruguppa
# Processing Record 45 of the Set 7 | bubaque
# Processing Record 46 of the Set 7 | port macquarie
# Processing Record 47 of the Set 7 | cabo san lucas
# Processing Record 48 of the Set 7 | huangpi
# Processing Record 49 of the Set 7 | machiques
# Processing Record 50 of the Set 7 | hunza
# Processing Record 1 of the Set 8 | chojnow
# Processing Record 2 of the Set 8 | ixtapa
# Processing Record 3 of the Set 8 | abalak
# Processing Record 4 of the Set 8 | seoul
# Processing Record 5 of the Set 8 | bulolo
# Processing Record 6 of the Set 8 | mizdah
# Processing Record 7 of the Set 8 | vardo
# Processing Record 8 of the Set 8 | zykovo
# Processing Record 9 of the Set 8 | esperance
# Processing Record 10 of the Set 8 | nikki
# Processing Record 11 of the Set 8 | burkhala
# Processing Record 12 of the Set 8 | pakokku
# Processing Record 13 of the Set 8 | hofn
# Processing Record 14 of the Set 8 | arkhangelos
# City not found. Skipping...
# Processing Record 15 of the Set 8 | kangaatsiaq
# Processing Record 16 of the Set 8 | karauzyak
# Processing Record 17 of the Set 8 | vostok
# Processing Record 18 of the Set 8 | la paz
# Processing Record 19 of the Set 8 | maniitsoq
# Processing Record 20 of the Set 8 | tsaratanana
# City not found. Skipping...
# Processing Record 21 of the Set 8 | emerald
# Processing Record 22 of the Set 8 | sungaipenuh
# Processing Record 23 of the Set 8 | port-gentil
# Processing Record 24 of the Set 8 | walvis bay
# Processing Record 25 of the Set 8 | menongue
# Processing Record 26 of the Set 8 | banda aceh
# Processing Record 27 of the Set 8 | shakawe
# Processing Record 28 of the Set 8 | kamenka
# Processing Record 29 of the Set 8 | dzhusaly
# Processing Record 30 of the Set 8 | juruti
# Processing Record 31 of the Set 8 | oranjemund
# Processing Record 32 of the Set 8 | ambanja
# City not found. Skipping...
# Processing Record 33 of the Set 8 | buchanan
# Processing Record 34 of the Set 8 | lagoa
# Processing Record 35 of the Set 8 | kungurtug
# Processing Record 36 of the Set 8 | kropotkin
# Processing Record 37 of the Set 8 | roswell
# Processing Record 38 of the Set 8 | eau claire
# Processing Record 39 of the Set 8 | macklin
# Processing Record 40 of the Set 8 | marsh harbour
# Processing Record 41 of the Set 8 | karaul
# Processing Record 42 of the Set 8 | kawalu
# Processing Record 43 of the Set 8 | mnogovershinnyy
# Processing Record 44 of the Set 8 | rupert
# Processing Record 45 of the Set 8 | maua
# Processing Record 46 of the Set 8 | geraldton
# Processing Record 47 of the Set 8 | tabou
# Processing Record 48 of the Set 8 | khorixas
# Processing Record 49 of the Set 8 | ballina
# Processing Record 50 of the Set 8 | cachoeira do sul
# Processing Record 1 of the Set 9 | iwaki
# Processing Record 2 of the Set 9 | kumluca
# Processing Record 3 of the Set 9 | saint george
# Processing Record 4 of the Set 9 | hay river
# Processing Record 5 of the Set 9 | san cristobal
# Processing Record 6 of the Set 9 | lolua
# Processing Record 7 of the Set 9 | la reforma
# Processing Record 8 of the Set 9 | huarmey
# City not found. Skipping...
# Processing Record 9 of the Set 9 | kupang
# Processing Record 10 of the Set 9 | bathsheba
# Processing Record 11 of the Set 9 | tlahualilo
# Processing Record 12 of the Set 9 | filingue
# Processing Record 13 of the Set 9 | carauari
# Processing Record 14 of the Set 9 | marathon
# Processing Record 15 of the Set 9 | zhigansk
# Processing Record 16 of the Set 9 | najran
# Processing Record 17 of the Set 9 | severo-yeniseyskiy
# Processing Record 18 of the Set 9 | xichang
# Processing Record 19 of the Set 9 | turukhansk
# Processing Record 20 of the Set 9 | bartica
# Processing Record 21 of the Set 9 | hami
# Processing Record 22 of the Set 9 | pisco
# City not found. Skipping...
# Processing Record 23 of the Set 9 | ucluelet
# Processing Record 24 of the Set 9 | coolum beach
# Processing Record 25 of the Set 9 | bidar
# Processing Record 26 of the Set 9 | phayao
# Processing Record 27 of the Set 9 | marawi
# Processing Record 28 of the Set 9 | katobu
# Processing Record 29 of the Set 9 | ballybofey
# Processing Record 30 of the Set 9 | terme
# Processing Record 31 of the Set 9 | manokwari
# Processing Record 32 of the Set 9 | la rioja
# Processing Record 33 of the Set 9 | katsuura
# Processing Record 34 of the Set 9 | russell
# Processing Record 35 of the Set 9 | samusu
# City not found. Skipping...
# Processing Record 36 of the Set 9 | port hedland
# Processing Record 37 of the Set 9 | ancud
# Processing Record 38 of the Set 9 | morgan hill
# Processing Record 39 of the Set 9 | samarai
# Processing Record 40 of the Set 9 | tautira
# Processing Record 41 of the Set 9 | culpeper
# Processing Record 42 of the Set 9 | epe
# Processing Record 43 of the Set 9 | san patricio
# Processing Record 44 of the Set 9 | krasnoselkup
# Processing Record 45 of the Set 9 | norfolk
# Processing Record 46 of the Set 9 | sindand
# City not found. Skipping...
# Processing Record 47 of the Set 9 | cap malheureux
# Processing Record 48 of the Set 9 | sal rei
# Processing Record 49 of the Set 9 | lavrentiya
# Processing Record 50 of the Set 9 | levokumskoye
# Processing Record 1 of the Set 10 | portland
# Processing Record 2 of the Set 10 | beaune
# Processing Record 3 of the Set 10 | meyungs
# Processing Record 4 of the Set 10 | sawakin
# Processing Record 5 of the Set 10 | yola
# Processing Record 6 of the Set 10 | drayton valley
# Processing Record 7 of the Set 10 | hailar
# Processing Record 8 of the Set 10 | kushmurun
# Processing Record 9 of the Set 10 | limbang
# Processing Record 10 of the Set 10 | muhos
# Processing Record 11 of the Set 10 | labutta
# Processing Record 12 of the Set 10 | paragominas
# Processing Record 13 of the Set 10 | north bend
# Processing Record 14 of the Set 10 | anadyr
# Processing Record 15 of the Set 10 | langsa
# Processing Record 16 of the Set 10 | korla
# Processing Record 17 of the Set 10 | namibe
# Processing Record 18 of the Set 10 | abeche
# Processing Record 19 of the Set 10 | pasighat
# Processing Record 20 of the Set 10 | kargasok
# Processing Record 21 of the Set 10 | fort saint john
# Processing Record 22 of the Set 10 | katha
# Processing Record 23 of the Set 10 | ginir
# Processing Record 24 of the Set 10 | necochea
# Processing Record 25 of the Set 10 | tilichiki
# Processing Record 26 of the Set 10 | boa viagem
# Processing Record 27 of the Set 10 | tommot
# Processing Record 28 of the Set 10 | beberibe
# Processing Record 29 of the Set 10 | umarkot
# Processing Record 30 of the Set 10 | mayo
# Processing Record 31 of the Set 10 | mastic
# Processing Record 32 of the Set 10 | nanortalik
# Processing Record 33 of the Set 10 | zyryanovsk
# Processing Record 34 of the Set 10 | barra do corda
# Processing Record 35 of the Set 10 | rodez
# Processing Record 36 of the Set 10 | tigre
# Processing Record 37 of the Set 10 | havre
# Processing Record 38 of the Set 10 | puerto suarez
# Processing Record 39 of the Set 10 | bandipur
# Processing Record 40 of the Set 10 | platanos
# City not found. Skipping...
# Processing Record 41 of the Set 10 | grand river south east
# Processing Record 42 of the Set 10 | guerrero negro
# Processing Record 43 of the Set 10 | manzil kamil
# Processing Record 44 of the Set 10 | dingle
# Processing Record 45 of the Set 10 | tazovskiy
# Processing Record 46 of the Set 10 | iquique
# Processing Record 47 of the Set 10 | tubruq
# Processing Record 48 of the Set 10 | svetlogorsk
# Processing Record 49 of the Set 10 | baijiantan
# Processing Record 50 of the Set 10 | tomatlan
# Processing Record 1 of the Set 11 | egvekinot
# Processing Record 2 of the Set 11 | kyren
# Processing Record 3 of the Set 11 | kefalos
# City not found. Skipping...
# Processing Record 4 of the Set 11 | kapenguria
# Processing Record 5 of the Set 11 | quelimane
# City not found. Skipping...
# Processing Record 6 of the Set 11 | lokosovo
# Processing Record 7 of the Set 11 | karwar
# Processing Record 8 of the Set 11 | coahuayana
# Processing Record 9 of the Set 11 | shenjiamen
# Processing Record 10 of the Set 11 | kushikino
# Processing Record 11 of the Set 11 | toliary
# City not found. Skipping...
# Processing Record 12 of the Set 11 | nyurba
# Processing Record 13 of the Set 11 | yangambi
# Processing Record 14 of the Set 11 | temaraia
# Processing Record 15 of the Set 11 | qaqortoq
# Processing Record 16 of the Set 11 | cockburn town
# Processing Record 17 of the Set 11 | kuche
# Processing Record 18 of the Set 11 | nhulunbuy
# Processing Record 19 of the Set 11 | san antonio
# Processing Record 20 of the Set 11 | zeya
# Processing Record 21 of the Set 11 | binga
# Processing Record 22 of the Set 11 | stekolnyy
# Processing Record 23 of the Set 11 | awjilah
# Processing Record 24 of the Set 11 | nome
# Processing Record 25 of the Set 11 | naze
# Processing Record 26 of the Set 11 | rocha
# Processing Record 27 of the Set 11 | baiyin
# Processing Record 28 of the Set 11 | atambua
# Processing Record 29 of the Set 11 | aleksandrovskiy zavod
# Processing Record 30 of the Set 11 | sisimiut
# Processing Record 31 of the Set 11 | wagar
# Processing Record 32 of the Set 11 | nabire
# Processing Record 33 of the Set 11 | general pico
# Processing Record 34 of the Set 11 | weihe
# Processing Record 35 of the Set 11 | provideniya
# Processing Record 36 of the Set 11 | washougal
# Processing Record 37 of the Set 11 | businga
# Processing Record 38 of the Set 11 | clarence town
# Processing Record 39 of the Set 11 | coruripe
# Processing Record 40 of the Set 11 | zhaoqing
# Processing Record 41 of the Set 11 | sibolga
# Processing Record 42 of the Set 11 | kibre mengist
# Processing Record 43 of the Set 11 | birjand
# Processing Record 44 of the Set 11 | vaitape
# Processing Record 45 of the Set 11 | olafsvik
# Processing Record 46 of the Set 11 | hernani
# Processing Record 47 of the Set 11 | belmonte
# Processing Record 48 of the Set 11 | orlik
# Processing Record 49 of the Set 11 | kavaratti
# Processing Record 50 of the Set 11 | alakurtti
# Processing Record 1 of the Set 12 | manaus
# Processing Record 2 of the Set 12 | finschhafen
# Processing Record 3 of the Set 12 | rolim de moura
# Processing Record 4 of the Set 12 | chumikan
# Processing Record 5 of the Set 12 | saint-pierre
# Processing Record 6 of the Set 12 | nizhneivkino
# Processing Record 7 of the Set 12 | rasht
# Processing Record 8 of the Set 12 | constitucion
# Processing Record 9 of the Set 12 | te anau
# Processing Record 10 of the Set 12 | haines junction
# Processing Record 11 of the Set 12 | paredon
# Processing Record 12 of the Set 12 | sept-iles
# Processing Record 13 of the Set 12 | kharp
# Processing Record 14 of the Set 12 | elizabeth city
# Processing Record 15 of the Set 12 | maragogi
# Processing Record 16 of the Set 12 | kanye
# Processing Record 17 of the Set 12 | havelock
# Processing Record 18 of the Set 12 | kiama
# Processing Record 19 of the Set 12 | chaozhou
# Processing Record 20 of the Set 12 | gayeri
# Processing Record 21 of the Set 12 | pedreira
# Processing Record 22 of the Set 12 | turayf
# Processing Record 23 of the Set 12 | poum
# Processing Record 24 of the Set 12 | salalah
# Processing Record 25 of the Set 12 | nuuk
# Processing Record 26 of the Set 12 | mildura
# Processing Record 27 of the Set 12 | capitan bado
# Processing Record 28 of the Set 12 | aasiaat
# Processing Record 29 of the Set 12 | obama
# Processing Record 30 of the Set 12 | raga
# Processing Record 31 of the Set 12 | villa maria
# Processing Record 32 of the Set 12 | ahipara
# Processing Record 33 of the Set 12 | rutana
# Processing Record 34 of the Set 12 | lockhart
# Processing Record 35 of the Set 12 | roald
# Processing Record 36 of the Set 12 | nouakchott
# Processing Record 37 of the Set 12 | lancaster
# Processing Record 38 of the Set 12 | praia
# Processing Record 39 of the Set 12 | myitkyina
# Processing Record 40 of the Set 12 | panaba
# Processing Record 41 of the Set 12 | boyolangu
# Processing Record 42 of the Set 12 | prince rupert
# Processing Record 43 of the Set 12 | mizan teferi
# Processing Record 44 of the Set 12 | tevaitoa
# Processing Record 45 of the Set 12 | buala
# Processing Record 46 of the Set 12 | kantemirovka
# Processing Record 47 of the Set 12 | falealupo
# City not found. Skipping...
# Processing Record 48 of the Set 12 | itoman
# Processing Record 49 of the Set 12 | williston
# Processing Record 50 of the Set 12 | san francisco
# Processing Record 1 of the Set 13 | seminole
# Processing Record 2 of the Set 13 | moron
# Processing Record 3 of the Set 13 | sorong
# Processing Record 4 of the Set 13 | naryshkino
# Processing Record 5 of the Set 13 | ossora
# Processing Record 6 of the Set 13 | arman
# Processing Record 7 of the Set 13 | yuci
# Processing Record 8 of the Set 13 | hailey
# Processing Record 9 of the Set 13 | xacmaz
# Processing Record 10 of the Set 13 | kem
# Processing Record 11 of the Set 13 | baruun-urt
# Processing Record 12 of the Set 13 | aksu
# Processing Record 13 of the Set 13 | talcahuano
# Processing Record 14 of the Set 13 | kavieng
# Processing Record 15 of the Set 13 | baependi
# Processing Record 16 of the Set 13 | camana
# City not found. Skipping...
# Processing Record 17 of the Set 13 | pangai
# Processing Record 18 of the Set 13 | mandalgovi
# Processing Record 19 of the Set 13 | kazalinsk
# Processing Record 20 of the Set 13 | dossor
# Processing Record 21 of the Set 13 | luwuk
# Processing Record 22 of the Set 13 | luanda
# Processing Record 23 of the Set 13 | alice springs
# Processing Record 24 of the Set 13 | isla vista
# Processing Record 25 of the Set 13 | ust-shonosha
# Processing Record 26 of the Set 13 | owerri
# Processing Record 27 of the Set 13 | matagami
# Processing Record 28 of the Set 13 | umba
# Processing Record 29 of the Set 13 | ambilobe
# Processing Record 30 of the Set 13 | erenhot
# Processing Record 31 of the Set 13 | batemans bay
# Processing Record 32 of the Set 13 | havoysund
# Processing Record 33 of the Set 13 | holbeach
# Processing Record 34 of the Set 13 | kostomuksha
# Processing Record 35 of the Set 13 | caceres
# Processing Record 36 of the Set 13 | nieuw amsterdam
# Processing Record 37 of the Set 13 | tigil
# Processing Record 38 of the Set 13 | vangaindrano
# Processing Record 39 of the Set 13 | hoopstad
# Processing Record 40 of the Set 13 | kuzhithurai
# Processing Record 41 of the Set 13 | cap-aux-meules
# Processing Record 42 of the Set 13 | lalganj
# Processing Record 43 of the Set 13 | ceyhan
# Processing Record 44 of the Set 13 | springfield
# Processing Record 45 of the Set 13 | manta
# Processing Record 46 of the Set 13 | nova olimpia
# Processing Record 47 of the Set 13 | doctor pedro p. pena
# Processing Record 48 of the Set 13 | arlit
# Processing Record 49 of the Set 13 | catuday
# Processing Record 50 of the Set 13 | kovdor
# Processing Record 1 of the Set 14 | benguela
# Processing Record 2 of the Set 14 | macon
# Processing Record 3 of the Set 14 | wahran
# Processing Record 4 of the Set 14 | wajir
# Processing Record 5 of the Set 14 | palaiokhora
# City not found. Skipping...
# Processing Record 6 of the Set 14 | mundo nuevo
# Processing Record 7 of the Set 14 | tuy hoa
# Processing Record 8 of the Set 14 | reriutaba
# Processing Record 9 of the Set 14 | madona
# Processing Record 10 of the Set 14 | luderitz
# Processing Record 11 of the Set 14 | umzimvubu
# Processing Record 12 of the Set 14 | louisbourg
# Processing Record 13 of the Set 14 | morant bay
# Processing Record 14 of the Set 14 | kaeo
# Processing Record 15 of the Set 14 | srednekolymsk
# Processing Record 16 of the Set 14 | barlinek
# Processing Record 17 of the Set 14 | charagua
# Processing Record 18 of the Set 14 | yomitan
# Processing Record 19 of the Set 14 | roebourne
# Processing Record 20 of the Set 14 | kimbe
# Processing Record 21 of the Set 14 | sistranda
# Processing Record 22 of the Set 14 | alotau
# Processing Record 23 of the Set 14 | viedma
# Processing Record 24 of the Set 14 | palana
# Processing Record 25 of the Set 14 | cabras
# Processing Record 26 of the Set 14 | vanavara
# Processing Record 27 of the Set 14 | kautokeino
# Processing Record 28 of the Set 14 | kalevala
# Processing Record 29 of the Set 14 | praia da vitoria
# Processing Record 30 of the Set 14 | ambodifototra
# Processing Record 31 of the Set 14 | rio gallegos
# Processing Record 32 of the Set 14 | iquitos
# City not found. Skipping...
# Processing Record 33 of the Set 14 | nouadhibou
# Processing Record 34 of the Set 14 | srandakan
# Processing Record 35 of the Set 14 | batagay-alyta
# Processing Record 36 of the Set 14 | alofi
# Processing Record 37 of the Set 14 | mirnyy
# Processing Record 38 of the Set 14 | aketi
# Processing Record 39 of the Set 14 | saleaula
# City not found. Skipping...
# Processing Record 40 of the Set 14 | bocaiuva
# Processing Record 41 of the Set 14 | san buenaventura
# Processing Record 42 of the Set 14 | arandis
# Processing Record 43 of the Set 14 | vorsma
# Processing Record 44 of the Set 14 | jind
# Processing Record 45 of the Set 14 | gravdal
# Processing Record 46 of the Set 14 | chernyshevskiy
# Processing Record 47 of the Set 14 | sioux lookout
# Processing Record 48 of the Set 14 | tieling
# Processing Record 49 of the Set 14 | fairview
# Processing Record 50 of the Set 14 | esso
# Processing Record 1 of the Set 15 | ngukurr
# Processing Record 2 of the Set 15 | aksu
# Processing Record 3 of the Set 15 | baghdad
# Processing Record 4 of the Set 15 | tornio
# Processing Record 5 of the Set 15 | palu
# Processing Record 6 of the Set 15 | tuatapere
# Processing Record 7 of the Set 15 | tasbuget
# Processing Record 8 of the Set 15 | cazaje
# Processing Record 9 of the Set 15 | chaska
# Processing Record 10 of the Set 15 | balakovo
# Processing Record 11 of the Set 15 | sorland
# Processing Record 12 of the Set 15 | kamen-rybolov
# Processing Record 13 of the Set 15 | pemangkat
# Processing Record 14 of the Set 15 | yialos
# City not found. Skipping...
# Processing Record 15 of the Set 15 | uruzgan
# City not found. Skipping...
# Processing Record 16 of the Set 15 | bhiwani
# Processing Record 17 of the Set 15 | camargo
# Processing Record 18 of the Set 15 | calbuco
# Processing Record 19 of the Set 15 | buritizeiro
# Processing Record 20 of the Set 15 | nevinnomyssk
# Processing Record 21 of the Set 15 | anuradhapura
# Processing Record 22 of the Set 15 | vyartsilya
# Processing Record 23 of the Set 15 | high level
# Processing Record 24 of the Set 15 | xuddur
# Processing Record 25 of the Set 15 | tabuk
# Processing Record 26 of the Set 15 | wahiawa
# Processing Record 27 of the Set 15 | carolina
# Processing Record 28 of the Set 15 | seremban
# Processing Record 29 of the Set 15 | upington
# Processing Record 30 of the Set 15 | lubango
# Processing Record 31 of the Set 15 | manoel urbano
# Processing Record 32 of the Set 15 | attawapiskat
# Processing Record 33 of the Set 15 | vallenar
# Processing Record 34 of the Set 15 | kongolo
# Processing Record 35 of the Set 15 | les cayes
# Processing Record 36 of the Set 15 | cabiraoan
# Processing Record 37 of the Set 15 | berezovyy
# Processing Record 38 of the Set 15 | multai
# Processing Record 39 of the Set 15 | porbandar
# Processing Record 40 of the Set 15 | port keats
# Processing Record 41 of the Set 15 | higuey
# Processing Record 42 of the Set 15 | havre-saint-pierre
# Processing Record 43 of the Set 15 | nasirabad
# Processing Record 44 of the Set 15 | sovetskiy
# Processing Record 45 of the Set 15 | selenduma
# Processing Record 46 of the Set 15 | lethem
# Processing Record 47 of the Set 15 | syracuse
# Processing Record 48 of the Set 15 | magione
# Processing Record 49 of the Set 15 | worland
# Processing Record 50 of the Set 15 | shache
# Processing Record 1 of the Set 16 | warqla
# Processing Record 2 of the Set 16 | cobija
# Processing Record 3 of the Set 16 | tabiauea
# Processing Record 4 of the Set 16 | prainha
# Processing Record 5 of the Set 16 | goundam
# Processing Record 6 of the Set 16 | revin
# Processing Record 7 of the Set 16 | ust-kuyga
# Processing Record 8 of the Set 16 | novosergiyevka
# Processing Record 9 of the Set 16 | bodden town
# Processing Record 10 of the Set 16 | dasoguz
# Processing Record 11 of the Set 16 | booue
# Processing Record 12 of the Set 16 | launceston
# Processing Record 13 of the Set 16 | leh
# Processing Record 14 of the Set 16 | matveyevka
# Processing Record 15 of the Set 16 | yuzhnyy
# Processing Record 16 of the Set 16 | polignano a mare
# Processing Record 17 of the Set 16 | faya
# Processing Record 18 of the Set 16 | pokanayevka
# Processing Record 19 of the Set 16 | ondorhaan
# Processing Record 20 of the Set 16 | evensk
# Processing Record 21 of the Set 16 | vuktyl
# Processing Record 22 of the Set 16 | zyryanka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)

# Order the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_weather_df = city_weather_df[new_column_order]

# %%
city_weather_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Sakakah      SA  29.9697   40.2064    107.38         9           8
# 1   Jamestown      US  42.0970  -79.2353     87.39        60          40
# 2       Bluff      NZ -46.6000  168.3333     39.79        68          88
# 3  Trenggalek      ID  -8.0500  111.7167     73.13        90          87
# 4       Lensk      RU  60.7253  114.9278     59.00        99         100
#
#    Wind Speed Current Description
# 0       10.25           clear sky
# 1       11.50    scattered clouds
# 2        6.91     overcast clouds
# 3        3.49     overcast clouds
# 4        1.90     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_weather_df.to_csv(output_data_file, index_label="City_ID")
