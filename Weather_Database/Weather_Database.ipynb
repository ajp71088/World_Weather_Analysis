# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Check the number of cities
len(cities)
# Out:
# 726

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    
    # Create endpoint URL with each city
    city_url = base_url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | hobart
# Processing Record 2 of the Set 1 | luderitz
# Processing Record 3 of the Set 1 | kavaratti
# Processing Record 4 of the Set 1 | puerto ayora
# Processing Record 5 of the Set 1 | vysokogornyy
# Processing Record 6 of the Set 1 | souillac
# Processing Record 7 of the Set 1 | husavik
# Processing Record 8 of the Set 1 | ushuaia
# Processing Record 9 of the Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of the Set 1 | thompson
# Processing Record 11 of the Set 1 | luebo
# Processing Record 12 of the Set 1 | busselton
# Processing Record 13 of the Set 1 | vaini
# Processing Record 14 of the Set 1 | kapenguria
# Processing Record 15 of the Set 1 | ossora
# Processing Record 16 of the Set 1 | babanusah
# City not found. Skipping...
# Processing Record 17 of the Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 18 of the Set 1 | jalu
# Processing Record 19 of the Set 1 | port alfred
# Processing Record 20 of the Set 1 | karibib
# Processing Record 21 of the Set 1 | hilo
# Processing Record 22 of the Set 1 | east london
# Processing Record 23 of the Set 1 | klaksvik
# Processing Record 24 of the Set 1 | arraial do cabo
# Processing Record 25 of the Set 1 | acapulco
# Processing Record 26 of the Set 1 | kuznechnoye
# Processing Record 27 of the Set 1 | tommot
# Processing Record 28 of the Set 1 | victoria
# Processing Record 29 of the Set 1 | saldanha
# Processing Record 30 of the Set 1 | georgetown
# Processing Record 31 of the Set 1 | galion
# Processing Record 32 of the Set 1 | avera
# Processing Record 33 of the Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of the Set 1 | norman wells
# Processing Record 35 of the Set 1 | mataura
# Processing Record 36 of the Set 1 | tiksi
# Processing Record 37 of the Set 1 | hilton head island
# Processing Record 38 of the Set 1 | cayenne
# Processing Record 39 of the Set 1 | novoplatnirovskaya
# Processing Record 40 of the Set 1 | comodoro rivadavia
# Processing Record 41 of the Set 1 | hihifo
# City not found. Skipping...
# Processing Record 42 of the Set 1 | itacare
# Processing Record 43 of the Set 1 | bluff
# Processing Record 44 of the Set 1 | tanete
# Processing Record 45 of the Set 1 | butaritari
# Processing Record 46 of the Set 1 | thunder bay
# Processing Record 47 of the Set 1 | pergamino
# Processing Record 48 of the Set 1 | new norfolk
# Processing Record 49 of the Set 1 | rikitea
# Processing Record 50 of the Set 1 | bethel
# Processing Record 1 of the Set 2 | nanortalik
# Processing Record 2 of the Set 2 | yenagoa
# Processing Record 3 of the Set 2 | hermanus
# Processing Record 4 of the Set 2 | muhos
# Processing Record 5 of the Set 2 | jamestown
# Processing Record 6 of the Set 2 | dublin
# Processing Record 7 of the Set 2 | khatanga
# Processing Record 8 of the Set 2 | airai
# Processing Record 9 of the Set 2 | bratsk
# Processing Record 10 of the Set 2 | kapaa
# Processing Record 11 of the Set 2 | faanui
# Processing Record 12 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of the Set 2 | cascais
# Processing Record 14 of the Set 2 | marystown
# Processing Record 15 of the Set 2 | puli
# Processing Record 16 of the Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of the Set 2 | saskylakh
# Processing Record 18 of the Set 2 | pevek
# Processing Record 19 of the Set 2 | yulara
# Processing Record 20 of the Set 2 | matamoros
# Processing Record 21 of the Set 2 | tiarei
# Processing Record 22 of the Set 2 | emiliano zapata
# Processing Record 23 of the Set 2 | avarua
# Processing Record 24 of the Set 2 | san quintin
# Processing Record 25 of the Set 2 | khormuj
# City not found. Skipping...
# Processing Record 26 of the Set 2 | atuona
# Processing Record 27 of the Set 2 | rundu
# Processing Record 28 of the Set 2 | tiznit
# Processing Record 29 of the Set 2 | lokosovo
# Processing Record 30 of the Set 2 | upernavik
# Processing Record 31 of the Set 2 | carnarvon
# Processing Record 32 of the Set 2 | harper
# Processing Record 33 of the Set 2 | pangnirtung
# Processing Record 34 of the Set 2 | kodiak
# Processing Record 35 of the Set 2 | vardo
# Processing Record 36 of the Set 2 | urucui
# Processing Record 37 of the Set 2 | emba
# Processing Record 38 of the Set 2 | lappeenranta
# Processing Record 39 of the Set 2 | sampit
# Processing Record 40 of the Set 2 | maningrida
# Processing Record 41 of the Set 2 | sinnamary
# Processing Record 42 of the Set 2 | bayevo
# Processing Record 43 of the Set 2 | atambua
# Processing Record 44 of the Set 2 | cockburn town
# Processing Record 45 of the Set 2 | haimen
# Processing Record 46 of the Set 2 | tungkang
# City not found. Skipping...
# Processing Record 47 of the Set 2 | lebu
# Processing Record 48 of the Set 2 | kasongo-lunda
# Processing Record 49 of the Set 2 | cherskiy
# Processing Record 50 of the Set 2 | lasa
# Processing Record 1 of the Set 3 | qasigiannguit
# Processing Record 2 of the Set 3 | fortuna
# Processing Record 3 of the Set 3 | fort nelson
# Processing Record 4 of the Set 3 | ostrovnoy
# Processing Record 5 of the Set 3 | omsukchan
# Processing Record 6 of the Set 3 | moerewa
# Processing Record 7 of the Set 3 | buala
# Processing Record 8 of the Set 3 | lluta
# Processing Record 9 of the Set 3 | yellowknife
# Processing Record 10 of the Set 3 | mpanda
# Processing Record 11 of the Set 3 | micheweni
# Processing Record 12 of the Set 3 | jinji
# Processing Record 13 of the Set 3 | hammerfest
# Processing Record 14 of the Set 3 | chapais
# Processing Record 15 of the Set 3 | qaanaaq
# Processing Record 16 of the Set 3 | sitka
# Processing Record 17 of the Set 3 | hasaki
# Processing Record 18 of the Set 3 | katsuura
# Processing Record 19 of the Set 3 | pitimbu
# Processing Record 20 of the Set 3 | dongobesh
# Processing Record 21 of the Set 3 | listvyanskiy
# Processing Record 22 of the Set 3 | ancud
# Processing Record 23 of the Set 3 | hailar
# Processing Record 24 of the Set 3 | tasiilaq
# Processing Record 25 of the Set 3 | aleksandrov gay
# Processing Record 26 of the Set 3 | nouadhibou
# Processing Record 27 of the Set 3 | alice springs
# Processing Record 28 of the Set 3 | misratah
# Processing Record 29 of the Set 3 | encruzilhada do sul
# Processing Record 30 of the Set 3 | namatanai
# Processing Record 31 of the Set 3 | dwarka
# Processing Record 32 of the Set 3 | albany
# Processing Record 33 of the Set 3 | yialos
# City not found. Skipping...
# Processing Record 34 of the Set 3 | cape town
# Processing Record 35 of the Set 3 | andenes
# Processing Record 36 of the Set 3 | barrow
# Processing Record 37 of the Set 3 | ribeira grande
# Processing Record 38 of the Set 3 | twentynine palms
# Processing Record 39 of the Set 3 | port-gentil
# Processing Record 40 of the Set 3 | karoi
# Processing Record 41 of the Set 3 | bambous virieux
# Processing Record 42 of the Set 3 | castro
# Processing Record 43 of the Set 3 | pacific grove
# Processing Record 44 of the Set 3 | berlevag
# Processing Record 45 of the Set 3 | talnakh
# Processing Record 46 of the Set 3 | riyadh
# Processing Record 47 of the Set 3 | dunedin
# Processing Record 48 of the Set 3 | cap malheureux
# Processing Record 49 of the Set 3 | lethem
# Processing Record 50 of the Set 3 | high level
# Processing Record 1 of the Set 4 | redhakhol
# City not found. Skipping...
# Processing Record 2 of the Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of the Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of the Set 4 | tuktoyaktuk
# Processing Record 5 of the Set 4 | miranda
# Processing Record 6 of the Set 4 | pahrump
# Processing Record 7 of the Set 4 | gravdal
# Processing Record 8 of the Set 4 | khorramshahr
# Processing Record 9 of the Set 4 | edendale
# Processing Record 10 of the Set 4 | burdur
# Processing Record 11 of the Set 4 | portobelo
# Processing Record 12 of the Set 4 | whitehorse
# Processing Record 13 of the Set 4 | college
# Processing Record 14 of the Set 4 | simojovel
# Processing Record 15 of the Set 4 | salta
# Processing Record 16 of the Set 4 | visby
# Processing Record 17 of the Set 4 | morros
# Processing Record 18 of the Set 4 | codrington
# Processing Record 19 of the Set 4 | severo-kurilsk
# Processing Record 20 of the Set 4 | port elizabeth
# Processing Record 21 of the Set 4 | bredasdorp
# Processing Record 22 of the Set 4 | san patricio
# Processing Record 23 of the Set 4 | punta arenas
# Processing Record 24 of the Set 4 | sayat
# Processing Record 25 of the Set 4 | alta floresta
# Processing Record 26 of the Set 4 | carballo
# Processing Record 27 of the Set 4 | itaituba
# Processing Record 28 of the Set 4 | abu dhabi
# Processing Record 29 of the Set 4 | mar del plata
# Processing Record 30 of the Set 4 | bordighera
# Processing Record 31 of the Set 4 | ayorou
# Processing Record 32 of the Set 4 | bullhead city
# Processing Record 33 of the Set 4 | praia da vitoria
# Processing Record 34 of the Set 4 | warqla
# City not found. Skipping...
# Processing Record 35 of the Set 4 | komsomolskiy
# Processing Record 36 of the Set 4 | topolovgrad
# Processing Record 37 of the Set 4 | westport
# Processing Record 38 of the Set 4 | kaitangata
# Processing Record 39 of the Set 4 | sept-iles
# Processing Record 40 of the Set 4 | wahran
# City not found. Skipping...
# Processing Record 41 of the Set 4 | dikson
# Processing Record 42 of the Set 4 | kisangani
# Processing Record 43 of the Set 4 | constitucion
# Processing Record 44 of the Set 4 | lagoa
# Processing Record 45 of the Set 4 | kruisfontein
# Processing Record 46 of the Set 4 | port-cartier
# Processing Record 47 of the Set 4 | grand gaube
# Processing Record 48 of the Set 4 | provideniya
# Processing Record 49 of the Set 4 | severnoye
# Processing Record 50 of the Set 4 | hermiston
# Processing Record 1 of the Set 5 | lompoc
# Processing Record 2 of the Set 5 | mana
# Processing Record 3 of the Set 5 | torbay
# Processing Record 4 of the Set 5 | geraldton
# Processing Record 5 of the Set 5 | puri
# Processing Record 6 of the Set 5 | nikolskoye
# Processing Record 7 of the Set 5 | uribia
# Processing Record 8 of the Set 5 | hervey bay
# Processing Record 9 of the Set 5 | chagda
# City not found. Skipping...
# Processing Record 10 of the Set 5 | touros
# Processing Record 11 of the Set 5 | golpayegan
# Processing Record 12 of the Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of the Set 5 | nyrob
# Processing Record 14 of the Set 5 | cidreira
# Processing Record 15 of the Set 5 | energetik
# Processing Record 16 of the Set 5 | chuy
# Processing Record 17 of the Set 5 | mecca
# Processing Record 18 of the Set 5 | haines junction
# Processing Record 19 of the Set 5 | meulaboh
# Processing Record 20 of the Set 5 | hudiksvall
# Processing Record 21 of the Set 5 | ponta do sol
# Processing Record 22 of the Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of the Set 5 | te anau
# Processing Record 24 of the Set 5 | nieuw amsterdam
# Processing Record 25 of the Set 5 | ganderkesee
# Processing Record 26 of the Set 5 | north bend
# Processing Record 27 of the Set 5 | conde
# Processing Record 28 of the Set 5 | sibolga
# Processing Record 29 of the Set 5 | curumani
# Processing Record 30 of the Set 5 | la union
# Processing Record 31 of the Set 5 | ostersund
# Processing Record 32 of the Set 5 | iqaluit
# Processing Record 33 of the Set 5 | murmashi
# Processing Record 34 of the Set 5 | elizabeth city
# Processing Record 35 of the Set 5 | lolua
# City not found. Skipping...
# Processing Record 36 of the Set 5 | eyl
# Processing Record 37 of the Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 38 of the Set 5 | maues
# Processing Record 39 of the Set 5 | bathsheba
# Processing Record 40 of the Set 5 | yei
# Processing Record 41 of the Set 5 | yamada
# Processing Record 42 of the Set 5 | khonuu
# City not found. Skipping...
# Processing Record 43 of the Set 5 | kristiinankaupunki
# Processing Record 44 of the Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 45 of the Set 5 | zlatoustovsk
# City not found. Skipping...
# Processing Record 46 of the Set 5 | tura
# Processing Record 47 of the Set 5 | taywarah
# Processing Record 48 of the Set 5 | kutum
# Processing Record 49 of the Set 5 | marcona
# City not found. Skipping...
# Processing Record 50 of the Set 5 | caravelas
# Processing Record 1 of the Set 6 | jacareacanga
# Processing Record 2 of the Set 6 | nadvoitsy
# Processing Record 3 of the Set 6 | baykit
# Processing Record 4 of the Set 6 | huarmey
# Processing Record 5 of the Set 6 | minab
# Processing Record 6 of the Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of the Set 6 | francavilla fontana
# Processing Record 8 of the Set 6 | ghanzi
# Processing Record 9 of the Set 6 | pine bluff
# Processing Record 10 of the Set 6 | athabasca
# Processing Record 11 of the Set 6 | bossangoa
# Processing Record 12 of the Set 6 | kaoma
# Processing Record 13 of the Set 6 | waipawa
# Processing Record 14 of the Set 6 | tromso
# Processing Record 15 of the Set 6 | esperance
# Processing Record 16 of the Set 6 | wanaka
# Processing Record 17 of the Set 6 | aden
# Processing Record 18 of the Set 6 | amderma
# City not found. Skipping...
# Processing Record 19 of the Set 6 | qaqortoq
# Processing Record 20 of the Set 6 | isangel
# Processing Record 21 of the Set 6 | hithadhoo
# Processing Record 22 of the Set 6 | jinka
# Processing Record 23 of the Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of the Set 6 | tallahassee
# Processing Record 25 of the Set 6 | najran
# Processing Record 26 of the Set 6 | erdenet
# Processing Record 27 of the Set 6 | malwan
# City not found. Skipping...
# Processing Record 28 of the Set 6 | shakhtinsk
# Processing Record 29 of the Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of the Set 6 | dongsheng
# Processing Record 31 of the Set 6 | chokurdakh
# Processing Record 32 of the Set 6 | mount darwin
# Processing Record 33 of the Set 6 | marsa matruh
# Processing Record 34 of the Set 6 | tignere
# Processing Record 35 of the Set 6 | kununurra
# Processing Record 36 of the Set 6 | savelugu
# Processing Record 37 of the Set 6 | maceio
# Processing Record 38 of the Set 6 | talgar
# Processing Record 39 of the Set 6 | hovd
# Processing Record 40 of the Set 6 | vostok
# Processing Record 41 of the Set 6 | krasnoselkup
# Processing Record 42 of the Set 6 | tezu
# Processing Record 43 of the Set 6 | aranda de duero
# Processing Record 44 of the Set 6 | umm kaddadah
# Processing Record 45 of the Set 6 | xuddur
# Processing Record 46 of the Set 6 | magdagachi
# Processing Record 47 of the Set 6 | lamar
# Processing Record 48 of the Set 6 | sao joao da barra
# Processing Record 49 of the Set 6 | karratha
# Processing Record 50 of the Set 6 | jerez
# Processing Record 1 of the Set 7 | valenca do piaui
# Processing Record 2 of the Set 7 | vadinsk
# Processing Record 3 of the Set 7 | ilulissat
# Processing Record 4 of the Set 7 | karistos
# City not found. Skipping...
# Processing Record 5 of the Set 7 | coetupo
# City not found. Skipping...
# Processing Record 6 of the Set 7 | marawi
# Processing Record 7 of the Set 7 | santa vitoria do palmar
# Processing Record 8 of the Set 7 | longyearbyen
# Processing Record 9 of the Set 7 | samarai
# Processing Record 10 of the Set 7 | maloy
# Processing Record 11 of the Set 7 | birao
# Processing Record 12 of the Set 7 | paamiut
# Processing Record 13 of the Set 7 | siukh
# Processing Record 14 of the Set 7 | sahuaripa
# Processing Record 15 of the Set 7 | akkudah
# City not found. Skipping...
# Processing Record 16 of the Set 7 | biak
# Processing Record 17 of the Set 7 | yurino
# Processing Record 18 of the Set 7 | talakan
# Processing Record 19 of the Set 7 | baculin
# Processing Record 20 of the Set 7 | resistencia
# Processing Record 21 of the Set 7 | buraydah
# Processing Record 22 of the Set 7 | pisco
# Processing Record 23 of the Set 7 | sur
# Processing Record 24 of the Set 7 | samusu
# City not found. Skipping...
# Processing Record 25 of the Set 7 | blackfoot
# Processing Record 26 of the Set 7 | maniitsoq
# Processing Record 27 of the Set 7 | khandyga
# Processing Record 28 of the Set 7 | barawe
# City not found. Skipping...
# Processing Record 29 of the Set 7 | bakel
# Processing Record 30 of the Set 7 | banepa
# Processing Record 31 of the Set 7 | gravelbourg
# Processing Record 32 of the Set 7 | bangui
# Processing Record 33 of the Set 7 | olinda
# Processing Record 34 of the Set 7 | aras
# Processing Record 35 of the Set 7 | mentok
# City not found. Skipping...
# Processing Record 36 of the Set 7 | richards bay
# Processing Record 37 of the Set 7 | inhambane
# Processing Record 38 of the Set 7 | evensk
# Processing Record 39 of the Set 7 | lokoja
# Processing Record 40 of the Set 7 | camopi
# Processing Record 41 of the Set 7 | pordenone
# Processing Record 42 of the Set 7 | san pedro
# Processing Record 43 of the Set 7 | aquiraz
# Processing Record 44 of the Set 7 | mahebourg
# Processing Record 45 of the Set 7 | catamarca
# Processing Record 46 of the Set 7 | dingle
# Processing Record 47 of the Set 7 | marzuq
# Processing Record 48 of the Set 7 | novosheshminsk
# Processing Record 49 of the Set 7 | sosnovo-ozerskoye
# Processing Record 50 of the Set 7 | lundazi
# Processing Record 1 of the Set 8 | kangasala
# Processing Record 2 of the Set 8 | narsaq
# Processing Record 3 of the Set 8 | manzanillo
# Processing Record 4 of the Set 8 | santa fe
# Processing Record 5 of the Set 8 | daliang
# Processing Record 6 of the Set 8 | beringovskiy
# Processing Record 7 of the Set 8 | mergui
# City not found. Skipping...
# Processing Record 8 of the Set 8 | makaryev
# Processing Record 9 of the Set 8 | udachnyy
# Processing Record 10 of the Set 8 | kuala terengganu
# Processing Record 11 of the Set 8 | staroderevyankovskaya
# Processing Record 12 of the Set 8 | saint-louis
# Processing Record 13 of the Set 8 | vezirkopru
# Processing Record 14 of the Set 8 | kahului
# Processing Record 15 of the Set 8 | sergeyevka
# Processing Record 16 of the Set 8 | kieta
# Processing Record 17 of the Set 8 | gueret
# Processing Record 18 of the Set 8 | kjopsvik
# Processing Record 19 of the Set 8 | panjab
# Processing Record 20 of the Set 8 | agirish
# Processing Record 21 of the Set 8 | taltal
# Processing Record 22 of the Set 8 | pacifica
# Processing Record 23 of the Set 8 | batos
# Processing Record 24 of the Set 8 | killin
# Processing Record 25 of the Set 8 | dharchula
# Processing Record 26 of the Set 8 | belen
# Processing Record 27 of the Set 8 | coquimbo
# Processing Record 28 of the Set 8 | clyde river
# Processing Record 29 of the Set 8 | dawei
# Processing Record 30 of the Set 8 | broken hill
# Processing Record 31 of the Set 8 | nome
# Processing Record 32 of the Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 33 of the Set 8 | necochea
# Processing Record 34 of the Set 8 | pafos
# Processing Record 35 of the Set 8 | gushikawa
# Processing Record 36 of the Set 8 | saint george
# Processing Record 37 of the Set 8 | fort morgan
# Processing Record 38 of the Set 8 | barbar
# City not found. Skipping...
# Processing Record 39 of the Set 8 | rawson
# Processing Record 40 of the Set 8 | mount isa
# Processing Record 41 of the Set 8 | sangar
# Processing Record 42 of the Set 8 | gweta
# Processing Record 43 of the Set 8 | bac lieu
# Processing Record 44 of the Set 8 | grindavik
# Processing Record 45 of the Set 8 | wewak
# Processing Record 46 of the Set 8 | labutta
# City not found. Skipping...
# Processing Record 47 of the Set 8 | gat
# Processing Record 48 of the Set 8 | miri
# Processing Record 49 of the Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 50 of the Set 8 | stephenville
# Processing Record 1 of the Set 9 | tena
# Processing Record 2 of the Set 9 | tuatapere
# Processing Record 3 of the Set 9 | lavrentiya
# Processing Record 4 of the Set 9 | tchollire
# Processing Record 5 of the Set 9 | ouadda
# Processing Record 6 of the Set 9 | teberda
# Processing Record 7 of the Set 9 | nayoro
# Processing Record 8 of the Set 9 | wanning
# Processing Record 9 of the Set 9 | mehamn
# Processing Record 10 of the Set 9 | salinopolis
# Processing Record 11 of the Set 9 | myaundzha
# Processing Record 12 of the Set 9 | davydivka
# Processing Record 13 of the Set 9 | vila franca do campo
# Processing Record 14 of the Set 9 | bom jesus do itabapoana
# Processing Record 15 of the Set 9 | camacha
# Processing Record 16 of the Set 9 | saurimo
# Processing Record 17 of the Set 9 | samana
# Processing Record 18 of the Set 9 | athens
# Processing Record 19 of the Set 9 | inyonga
# Processing Record 20 of the Set 9 | kosa
# Processing Record 21 of the Set 9 | tarudant
# City not found. Skipping...
# Processing Record 22 of the Set 9 | abbeville
# Processing Record 23 of the Set 9 | asau
# Processing Record 24 of the Set 9 | apac
# Processing Record 25 of the Set 9 | killybegs
# Processing Record 26 of the Set 9 | aksu
# Processing Record 27 of the Set 9 | jiddah
# City not found. Skipping...
# Processing Record 28 of the Set 9 | nagato
# Processing Record 29 of the Set 9 | takoradi
# Processing Record 30 of the Set 9 | leh
# Processing Record 31 of the Set 9 | kattivakkam
# Processing Record 32 of the Set 9 | tubruq
# City not found. Skipping...
# Processing Record 33 of the Set 9 | aklavik
# Processing Record 34 of the Set 9 | tynda
# Processing Record 35 of the Set 9 | fairlie
# Processing Record 36 of the Set 9 | poum
# Processing Record 37 of the Set 9 | labuhan
# Processing Record 38 of the Set 9 | davila
# Processing Record 39 of the Set 9 | bengkulu
# Processing Record 40 of the Set 9 | akdepe
# Processing Record 41 of the Set 9 | arsenal
# Processing Record 42 of the Set 9 | jucas
# Processing Record 43 of the Set 9 | hambantota
# Processing Record 44 of the Set 9 | angoche
# Processing Record 45 of the Set 9 | den helder
# Processing Record 46 of the Set 9 | vao
# Processing Record 47 of the Set 9 | sungairaya
# Processing Record 48 of the Set 9 | pavlohrad
# Processing Record 49 of the Set 9 | ulladulla
# Processing Record 50 of the Set 9 | maarianhamina
# Processing Record 1 of the Set 10 | tukums
# Processing Record 2 of the Set 10 | rockport
# Processing Record 3 of the Set 10 | huanuco
# Processing Record 4 of the Set 10 | san cristobal
# Processing Record 5 of the Set 10 | butte
# Processing Record 6 of the Set 10 | lewistown
# Processing Record 7 of the Set 10 | totskoye
# Processing Record 8 of the Set 10 | belmonte
# Processing Record 9 of the Set 10 | bubaque
# Processing Record 10 of the Set 10 | amapa
# Processing Record 11 of the Set 10 | mackay
# Processing Record 12 of the Set 10 | dingli
# Processing Record 13 of the Set 10 | shishou
# Processing Record 14 of the Set 10 | darhan
# Processing Record 15 of the Set 10 | weihe
# Processing Record 16 of the Set 10 | zhuhai
# Processing Record 17 of the Set 10 | santa lucia
# Processing Record 18 of the Set 10 | sao filipe
# Processing Record 19 of the Set 10 | karpathos
# Processing Record 20 of the Set 10 | hirara
# Processing Record 21 of the Set 10 | ambon
# Processing Record 22 of the Set 10 | barra do garcas
# Processing Record 23 of the Set 10 | miraflores
# Processing Record 24 of the Set 10 | verkhnyaya inta
# Processing Record 25 of the Set 10 | manica
# Processing Record 26 of the Set 10 | pangody
# Processing Record 27 of the Set 10 | barreirinha
# Processing Record 28 of the Set 10 | fairbanks
# Processing Record 29 of the Set 10 | fort saint james
# Processing Record 30 of the Set 10 | forestville
# Processing Record 31 of the Set 10 | imbituba
# Processing Record 32 of the Set 10 | nizwa
# Processing Record 33 of the Set 10 | orange cove
# Processing Record 34 of the Set 10 | lorengau
# Processing Record 35 of the Set 10 | kunnamangalam
# Processing Record 36 of the Set 10 | merauke
# Processing Record 37 of the Set 10 | longlac
# City not found. Skipping...
# Processing Record 38 of the Set 10 | at-bashi
# Processing Record 39 of the Set 10 | eregli
# Processing Record 40 of the Set 10 | guerrero negro
# Processing Record 41 of the Set 10 | shingu
# Processing Record 42 of the Set 10 | leningradskiy
# Processing Record 43 of the Set 10 | ahipara
# Processing Record 44 of the Set 10 | aykhal
# Processing Record 45 of the Set 10 | laguna
# Processing Record 46 of the Set 10 | homer
# Processing Record 47 of the Set 10 | ishigaki
# Processing Record 48 of the Set 10 | mengyin
# Processing Record 49 of the Set 10 | whitianga
# Processing Record 50 of the Set 10 | quatre cocos
# Processing Record 1 of the Set 11 | coihaique
# Processing Record 2 of the Set 11 | tucurui
# Processing Record 3 of the Set 11 | taoudenni
# Processing Record 4 of the Set 11 | lonar
# Processing Record 5 of the Set 11 | raudeberg
# Processing Record 6 of the Set 11 | buqayq
# City not found. Skipping...
# Processing Record 7 of the Set 11 | mount gambier
# Processing Record 8 of the Set 11 | rovaniemi
# Processing Record 9 of the Set 11 | lom sak
# Processing Record 10 of the Set 11 | saint-philippe
# Processing Record 11 of the Set 11 | olga
# Processing Record 12 of the Set 11 | mathbaria
# Processing Record 13 of the Set 11 | santo antonio do ica
# Processing Record 14 of the Set 11 | yarada
# Processing Record 15 of the Set 11 | korla
# Processing Record 16 of the Set 11 | bereda
# Processing Record 17 of the Set 11 | phalaborwa
# Processing Record 18 of the Set 11 | novyy buh
# Processing Record 19 of the Set 11 | okhotsk
# Processing Record 20 of the Set 11 | bar harbor
# Processing Record 21 of the Set 11 | hami
# Processing Record 22 of the Set 11 | xining
# Processing Record 23 of the Set 11 | villamontes
# Processing Record 24 of the Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 25 of the Set 11 | sanguem
# Processing Record 26 of the Set 11 | houma
# Processing Record 27 of the Set 11 | bogatoye
# Processing Record 28 of the Set 11 | chebsara
# Processing Record 29 of the Set 11 | shetpe
# Processing Record 30 of the Set 11 | bosaso
# Processing Record 31 of the Set 11 | taunggyi
# Processing Record 32 of the Set 11 | tianpeng
# Processing Record 33 of the Set 11 | gidam
# Processing Record 34 of the Set 11 | chara
# Processing Record 35 of the Set 11 | kavieng
# Processing Record 36 of the Set 11 | serenje
# Processing Record 37 of the Set 11 | toppenish
# Processing Record 38 of the Set 11 | tarrafal
# Processing Record 39 of the Set 11 | sheridan
# Processing Record 40 of the Set 11 | rio gallegos
# Processing Record 41 of the Set 11 | nalut
# Processing Record 42 of the Set 11 | karaul
# City not found. Skipping...
# Processing Record 43 of the Set 11 | kedrovyy
# Processing Record 44 of the Set 11 | yelizovo
# Processing Record 45 of the Set 11 | point pedro
# Processing Record 46 of the Set 11 | along
# Processing Record 47 of the Set 11 | charters towers
# Processing Record 48 of the Set 11 | nhulunbuy
# Processing Record 49 of the Set 11 | seminole
# Processing Record 50 of the Set 11 | kampot
# Processing Record 1 of the Set 12 | acucena
# Processing Record 2 of the Set 12 | southbridge
# Processing Record 3 of the Set 12 | christchurch
# Processing Record 4 of the Set 12 | progreso
# Processing Record 5 of the Set 12 | egvekinot
# Processing Record 6 of the Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 7 of the Set 12 | providencia
# Processing Record 8 of the Set 12 | oktyabrskoye
# Processing Record 9 of the Set 12 | aksarka
# Processing Record 10 of the Set 12 | mantua
# Processing Record 11 of the Set 12 | eskisehir
# Processing Record 12 of the Set 12 | sorvag
# City not found. Skipping...
# Processing Record 13 of the Set 12 | tunggol
# Processing Record 14 of the Set 12 | mangrol
# Processing Record 15 of the Set 12 | ugoofaaru
# Processing Record 16 of the Set 12 | kudahuvadhoo
# Processing Record 17 of the Set 12 | kenora
# Processing Record 18 of the Set 12 | alexandria
# Processing Record 19 of the Set 12 | smithers
# Processing Record 20 of the Set 12 | viedma
# Processing Record 21 of the Set 12 | tessalit
# Processing Record 22 of the Set 12 | alofi
# Processing Record 23 of the Set 12 | cabo san lucas
# Processing Record 24 of the Set 12 | morada nova
# Processing Record 25 of the Set 12 | vanimo
# Processing Record 26 of the Set 12 | saint-augustin
# Processing Record 27 of the Set 12 | amberg
# Processing Record 28 of the Set 12 | jasper
# Processing Record 29 of the Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 30 of the Set 12 | burica
# City not found. Skipping...
# Processing Record 31 of the Set 12 | laje
# Processing Record 32 of the Set 12 | road town
# Processing Record 33 of the Set 12 | sumbe
# Processing Record 34 of the Set 12 | logan lake
# Processing Record 35 of the Set 12 | mastic beach
# Processing Record 36 of the Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of the Set 12 | okha
# Processing Record 38 of the Set 12 | camana
# Processing Record 39 of the Set 12 | hailin
# Processing Record 40 of the Set 12 | port blair
# Processing Record 41 of the Set 12 | alamos
# Processing Record 42 of the Set 12 | nguiu
# City not found. Skipping...
# Processing Record 43 of the Set 12 | port augusta
# Processing Record 44 of the Set 12 | lephepe
# City not found. Skipping...
# Processing Record 45 of the Set 12 | mogadishu
# Processing Record 46 of the Set 12 | cabedelo
# Processing Record 47 of the Set 12 | inuvik
# Processing Record 48 of the Set 12 | erdaojiang
# Processing Record 49 of the Set 12 | kalmunai
# Processing Record 50 of the Set 12 | srednekolymsk
# Processing Record 1 of the Set 13 | san carlos de bariloche
# Processing Record 2 of the Set 13 | sulangan
# Processing Record 3 of the Set 13 | neiafu
# Processing Record 4 of the Set 13 | roma
# Processing Record 5 of the Set 13 | santa rosa
# Processing Record 6 of the Set 13 | kosh-agach
# Processing Record 7 of the Set 13 | kraskino
# Processing Record 8 of the Set 13 | ngunguru
# Processing Record 9 of the Set 13 | bargal
# City not found. Skipping...
# Processing Record 10 of the Set 13 | nyurba
# Processing Record 11 of the Set 13 | senador jose porfirio
# Processing Record 12 of the Set 13 | gerede
# Processing Record 13 of the Set 13 | wang saphung
# Processing Record 14 of the Set 13 | sao felix do xingu
# Processing Record 15 of the Set 13 | naze
# Processing Record 16 of the Set 13 | belogradcik
# City not found. Skipping...
# Processing Record 17 of the Set 13 | siatista
# Processing Record 18 of the Set 13 | bud
# Processing Record 19 of the Set 13 | adrar
# Processing Record 20 of the Set 13 | camocim
# Processing Record 21 of the Set 13 | patacamaya
# Processing Record 22 of the Set 13 | salaga
# Processing Record 23 of the Set 13 | apiai
# Processing Record 24 of the Set 13 | arrecife
# Processing Record 25 of the Set 13 | namibe
# Processing Record 26 of the Set 13 | moindou
# Processing Record 27 of the Set 13 | champagnole
# Processing Record 28 of the Set 13 | villa maria
# Processing Record 29 of the Set 13 | ust-maya
# Processing Record 30 of the Set 13 | puntarenas
# Processing Record 31 of the Set 13 | kimbe
# Processing Record 32 of the Set 13 | palmas de monte alto
# Processing Record 33 of the Set 13 | collie
# Processing Record 34 of the Set 13 | buluang
# Processing Record 35 of the Set 13 | mao
# Processing Record 36 of the Set 13 | monte alegre
# Processing Record 37 of the Set 13 | santa cruz
# Processing Record 38 of the Set 13 | neuquen
# Processing Record 39 of the Set 13 | liwale
# Processing Record 40 of the Set 13 | longyan
# Processing Record 41 of the Set 13 | whyalla
# Processing Record 42 of the Set 13 | zeya
# Processing Record 43 of the Set 13 | mareeba
# Processing Record 44 of the Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 45 of the Set 13 | veraval
# Processing Record 46 of the Set 13 | manokwari
# Processing Record 47 of the Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 48 of the Set 13 | gari
# Processing Record 49 of the Set 13 | kalmar
# Processing Record 50 of the Set 13 | gladstone
# Processing Record 1 of the Set 14 | xai-xai
# Processing Record 2 of the Set 14 | ierapetra
# Processing Record 3 of the Set 14 | sigerfjord
# City not found. Skipping...
# Processing Record 4 of the Set 14 | nikolsk
# Processing Record 5 of the Set 14 | yerbogachen
# Processing Record 6 of the Set 14 | mildura
# Processing Record 7 of the Set 14 | birjand
# Processing Record 8 of the Set 14 | jarjis
# City not found. Skipping...
# Processing Record 9 of the Set 14 | skjervoy
# Processing Record 10 of the Set 14 | marti
# Processing Record 11 of the Set 14 | matara
# Processing Record 12 of the Set 14 | tabas
# Processing Record 13 of the Set 14 | broome
# Processing Record 14 of the Set 14 | gangotri
# City not found. Skipping...
# Processing Record 15 of the Set 14 | vila velha
# Processing Record 16 of the Set 14 | plettenberg bay
# Processing Record 17 of the Set 14 | zhetybay
# City not found. Skipping...
# Processing Record 18 of the Set 14 | makasar
# Processing Record 19 of the Set 14 | aflu
# City not found. Skipping...
# Processing Record 20 of the Set 14 | san jose
# Processing Record 21 of the Set 14 | byron bay
# Processing Record 22 of the Set 14 | shimoda
# Processing Record 23 of the Set 14 | barcelos
# Processing Record 24 of the Set 14 | duz
# City not found. Skipping...
# Processing Record 25 of the Set 14 | tsovinar
# Processing Record 26 of the Set 14 | bayeux
# Processing Record 27 of the Set 14 | henties bay
# Processing Record 28 of the Set 14 | pingliang
# Processing Record 29 of the Set 14 | svetlogorsk
# Processing Record 30 of the Set 14 | teneguiban
# City not found. Skipping...
# Processing Record 31 of the Set 14 | arcot
# Processing Record 32 of the Set 14 | talara
# Processing Record 33 of the Set 14 | maracaju
# Processing Record 34 of the Set 14 | muros
# Processing Record 35 of the Set 14 | ketchikan
# Processing Record 36 of the Set 14 | solnechnyy
# Processing Record 37 of the Set 14 | labrea
# Processing Record 38 of the Set 14 | banda aceh
# Processing Record 39 of the Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of the Set 14 | gazojak
# Processing Record 41 of the Set 14 | yoshida
# Processing Record 42 of the Set 14 | balikpapan
# Processing Record 43 of the Set 14 | kabala
# Processing Record 44 of the Set 14 | camiri
# Processing Record 45 of the Set 14 | kapit
# Processing Record 46 of the Set 14 | port macquarie
# Processing Record 47 of the Set 14 | kendari
# Processing Record 48 of the Set 14 | las lajas
# Processing Record 49 of the Set 14 | sabha
# Processing Record 50 of the Set 14 | toftir
# City not found. Skipping...
# Processing Record 1 of the Set 15 | ribeira brava
# Processing Record 2 of the Set 15 | lalsk
# Processing Record 3 of the Set 15 | sebrovo
# Processing Record 4 of the Set 15 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 5 of the Set 15 | nesbyen
# Processing Record 6 of the Set 15 | dehloran
# Processing Record 7 of the Set 15 | ixtapa
# Processing Record 8 of the Set 15 | cognac
# Processing Record 9 of the Set 15 | ballarat
# Processing Record 10 of the Set 15 | rabo de peixe
# Processing Record 11 of the Set 15 | uwayl
# City not found. Skipping...
# Processing Record 12 of the Set 15 | asnaes
# Processing Record 13 of the Set 15 | khash
# Processing Record 14 of the Set 15 | wilmington
# Processing Record 15 of the Set 15 | palamos
# Processing Record 16 of the Set 15 | muisne
# Processing Record 17 of the Set 15 | libreville
# Processing Record 18 of the Set 15 | plyussa
# Processing Record 19 of the Set 15 | lenger
# Processing Record 20 of the Set 15 | batagay
# Processing Record 21 of the Set 15 | hay river
# Processing Record 22 of the Set 15 | bat khela
# Processing Record 23 of the Set 15 | tual
# Processing Record 24 of the Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 25 of the Set 15 | jiuquan
# Processing Record 26 of the Set 15 | ekhabi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)

# Order the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_weather_df = city_weather_df[new_column_order]

# %%
city_weather_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hobart      AU -42.8794  147.3294     47.26        84          20
# 1      Luderitz      NA -26.6481   15.1594     64.18        47           0
# 2     Kavaratti      IN  10.5669   72.6420     81.12        77         100
# 3  Puerto Ayora      EC  -0.7393  -90.3518     75.16        94          53
# 4  Vysokogornyy      RU  50.1167  139.1500     55.65        92         100
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1        4.72           clear sky
# 2       20.67     overcast clouds
# 3        5.01       broken clouds
# 4        2.82     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_weather_df.to_csv(output_data_file, index_label="City_ID")
